# %%
# logger
import logging
logging.basicConfig(filename='logs.txt',
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.DEBUG)
logger = logging.getLogger()
logger.setLevel(level=logging.DEBUG)

# imports
import os
import ast
from fhirclient.client import FHIRClient
import configparser
import gradio_client
import fhirclient.models.observation as o
import fhirclient.models.annotation as a
from linkml_runtime import SchemaView
import pickle

# get the config
config = configparser.ConfigParser()
config.read('../config.ini')

# environment var
os.environ['OPENAI_API_KEY'] = config['AZURE']['AZURE_API_KEY']

# connection to FHIR server
settings = {
    'app_id': 'my_web_app',
    'api_base': 'http://localhost:8080/fhir/'
}
fhir_client = FHIRClient(settings=settings)

# connection to Gradlio server
HOST_URL = "http://localhost:7860"
llm_client = gradio_client.Client(HOST_URL)

# get observations
search = o.Observation.where(struct={'status': 'final'})
observations = search.perform_resources(fhir_client.server)

# load LinkML template
path_to_template = 'test.yaml'
sv = SchemaView(path_to_template)

# llm call function
def run_llm(prompt):

    # string of dict for input
    kwargs = dict(instruction_nochat=prompt)
    res = llm_client.predict(str(dict(kwargs)), api_name='/submit_nochat_api')

    # string of dict for output
    return ast.literal_eval(res)['response']

def get_completion_prompt(cls_name, sv, text):
    """Get the prompt for the given template."""

    # system prompt
    prompt = (
        "From the text below, extract the following entities in the following format (if available):\n\n"
    )

    # schema prompt is concatinated from prompts for each entity group
    for slot in sv.class_induced_slots(cls_name):
        
        # description of the entity group
        slot_prompt = slot.description

        # custom instruction for categorical entities
        if slot.range in sv.all_enums():
            enum_def = sv.get_enum(slot.range)
            pvs = [str(k) for k in enum_def.permissible_values.keys()]
            slot_prompt += f"Must be one of: {', '.join(pvs)}"

        # entity group prompt
        prompt += f"{slot.name}: <{slot_prompt}>\n"
    
    # concatinate the prompt with doctor's note
    prompt = f"{prompt}\n\nText:\n{text}\n\n===\n\n"
    return prompt

def annotate_observation(observation):
    
    # generate the prompt
    prompt = get_completion_prompt(
        cls_name='ClinicalNote',
        sv=sv,
        text = observation.code.text
    )
    
    # LLM call to extract entities 
    result = run_llm(prompt)
    
    # update observation
    observation.note = [a.Annotation({
        "authorString" : "Annotated by LLama2",
        "text": result
    })]
    observation.update(fhir_client.server)
# Out:
# Loaded as API: http://localhost:7860/ ✔

# %%
# annotate all observations
for observation in observations:
    annotate_observation(observation)

# %%
observations
# Out:
# [<fhirclient.models.observation.Observation at 0x10edf52d0>,
#  <fhirclient.models.observation.Observation at 0x110289150>,
#  <fhirclient.models.observation.Observation at 0x110289550>,
#  <fhirclient.models.observation.Observation at 0x1102898d0>,
#  <fhirclient.models.observation.Observation at 0x110298e10>,
#  <fhirclient.models.observation.Observation at 0x1102993d0>,
#  <fhirclient.models.observation.Observation at 0x11029ac90>,
#  <fhirclient.models.observation.Observation at 0x110298510>,
#  <fhirclient.models.observation.Observation at 0x110298110>,
#  <fhirclient.models.observation.Observation at 0x110298a10>,
#  <fhirclient.models.observation.Observation at 0x110299a90>,
#  <fhirclient.models.observation.Observation at 0x11029b350>,
#  <fhirclient.models.observation.Observation at 0x11029ad10>,
#  <fhirclient.models.observation.Observation at 0x110298e90>,
#  <fhirclient.models.observation.Observation at 0x110237510>,
#  <fhirclient.models.observation.Observation at 0x110235c50>,
#  <fhirclient.models.observation.Observation at 0x110237990>,
#  <fhirclient.models.observation.Observation at 0x11026de10>,
#  <fhirclient.models.observation.Observation at 0x11026ce50>,
#  <fhirclient.models.observation.Observation at 0x11026ccd0>]

# %%
with open('../data/observations_with_annotations.pkl', 'wb') as file:
    pickle.dump(observations_as_json, file)

# %%
observations_as_json = [a.as_json() for a in observations]

# %%
with open('../data/observations_with_annotations.pkl', 'rb') as file:
    test = pickle.load(file)
test
# Out:
# [{'id': '3',
#   'meta': {'lastUpdated': '2023-08-21T21:43:39.021+00:00',
#    'source': '#TVcOrjC9tnqQ5kVm',
#    'versionId': '2'},
#   'code': {'text': " During today's check-up, Mr. John Doe's blood glucose level was measured at 175 mg/dL. This reading indicates elevated glucose levels, potentially related to his diabetes management. It's important to continue monitoring his condition and adjust his treatment plan as needed."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities in the format you requested:\nage: Not available (as it is not mentioned in the text)\ngender: Male (as the patient\'s name is "Mr. John Doe")\nconditions:\n* Diabetes management\n\nobservations:\n* Blood glucose level: 175 mg/dL (measured during today\'s check-up)\nmedications: Not available (as the text does not mention any medication use by the patient)\nprocedures: Not available (as the text does not mention any procedures or therapies performed on the patient)'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '4',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.120+00:00',
#    'source': '#KRh7h7u1LSPYA55O',
#    'versionId': '1'},
#   'code': {'text': " Mr. Doe's recent lab results show a fasting blood sugar level of 190 mg/dL. This reading suggests a need for closer glycemic control and potential adjustments to his insulin regimen to better manage his diabetes."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': "  Sure! Here are the entities in the format you requested:\nage: Not available (as it is not mentioned in the text)\ngender: Male (as the patient's name, Mr. Doe, suggests a male gender)\nconditions: diabetes (as the text mentions the patient has diabetes and suggests a need for closer glycemic control and potential adjustments to his insulin regimen)\nobservations:\n* Lab results: fasting blood sugar level of 190 mg/dL\nmedications: Not available (as the text does not mention any information about medication use by the patient)\nprocedures: Not available (as the text does not mention any procedures or therapies performed on the patient)"}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '5',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.177+00:00',
#    'source': '#flvqr3hG6BGpdKIA',
#    'versionId': '1'},
#   'code': {'text': " In light of Mr. Doe's recent complaints of increased thirst and frequent urination, his hemoglobin A1c level was tested and found to be 8.9%. This elevated level points to ongoing challenges in maintaining optimal blood sugar control."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities that can be extracted from the text you provided:\nage: Not available (the patient\'s age is not mentioned in the text)\ngender: Male (based on the name "Mr. Doe")\nconditions:\n* Increased thirst\n* Frequent urination\n\nobservations:\n* Hemoglobin A1c level: 8.9%\n* Optimal blood sugar control\n\nmedications: Not available (the text does not mention any medication use by the patient)\nprocedures: Not available (the text does not mention any procedures or therapies performed on the patient)'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '6',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.227+00:00',
#    'source': '#NXnShAuzET6HgN0y',
#    'versionId': '1'},
#   'code': {'text': " During today's follow-up, Mr. Doe's postprandial blood glucose was recorded at 220 mg/dL. His continued hyperglycemia raises concerns about his adherence to dietary restrictions and medication regimen."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities that can be extracted from the text you provided:\n* age: Not available in the given text.\n* gender: Male (based on the name "Mr. Doe")\n* conditions: Hyperglycemia (raised as a concern due to continued high blood glucose levels)\n* observations:\n\t+ Lab data: Not available in the given text.\n\t+ Measurements: Not available in the given text.\n\t+ Vital signs: Not available in the given text.\n\t+ Clinical findings: None mentioned in the given text.\n\t+ Various scores: Not available in the given text.\n* medications:\n\t+ Medication name: Not available in the given text.\n\t+ Dose: Not available in the given text.\n\t+ Frequency: Not available in the given text.\n* procedures: None mentioned in the given text.\n* tests: None mentioned in the given text.'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '7',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.277+00:00',
#    'source': '#xIWEUtqh3WIItbV0',
#    'versionId': '1'},
#   'code': {'text': " Mr. Doe's continuous glucose monitoring revealed a nocturnal hypoglycemic event, with his blood sugar dropping to 55 mg/dL overnight. Adjustments to his insulin dosing and bedtime snack may help prevent future episodes."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities in the format you requested:\nage: Not available\ngender: Male\nconditions: hypoglycemic event\nobservations:\n* Lab data: Blood sugar level: 55 mg/dL\n* Measurements: None mentioned\n* Vital signs: None mentioned\n* Clinical findings: Nocturnal hypoglycemic event\n* Various scores: None mentioned\nmedications:\n* Insulin dosing: Adjustments made to his insulin dosing\n* Dose: Not available\n* Frequency: Not available\nprocedures:\n* Continuous glucose monitoring: Performed on the patient\n* Other procedures and therapies: None mentioned'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '8',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.325+00:00',
#    'source': '#9tAypL3UsR2ttYwO',
#    'versionId': '1'},
#   'code': {'text': " Today's assessment showed Mr. Doe's random blood glucose level to be 240 mg/dL. This sustained elevation underscores the importance of enhancing his self-management skills and increasing his physical activity."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': "  Sure, here are the entities in the format you requested:\nage: Not available (as it is not mentioned in the text)\ngender: Male (as the patient's name is Mr. Doe, which is typically used for male patients)\nconditions:\n* Elevated random blood glucose level (as mentioned in the text)\nobservations:\n* Random blood glucose level: 240 mg/dL (as mentioned in the text)\nmedications: Not available (as there is no information about medication use in the text)\nprocedures: Not available (as there is no information about procedures or therapies performed on the patient in the text)"}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '9',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.369+00:00',
#    'source': '#rWzNzBC8pwYpoqmW',
#    'versionId': '1'},
#   'code': {'text': " Mr. Doe's recent HbA1c measurement came in at 9.4%, signaling the need for more intensive intervention to address his diabetes control. A comprehensive review of his treatment plan is advised."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities that can be extracted from the text you provided:\nage: Not available\ngender: Male (Mr.)\nconditions: Diabetes\nobservations:\n* HbA1c measurement: 9.4%\nmedications: Not available\nprocedures: Not available\n\nNote that some of these entities may not be explicitly mentioned in the text, but can be inferred based on the information provided.'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '10',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.414+00:00',
#    'source': '#QQRY11OtoF1E9Fdn',
#    'versionId': '1'},
#   'code': {'text': " During the annual diabetes review, Mr. Doe's blood pressure was elevated at 140/90 mmHg, possibly contributing to his glucose instability. Managing his hypertension in conjunction with diabetes is essential."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities that can be extracted from the text you provided:\nage: Not available\ngender: Male (Mr. Doe)\nconditions:\n* Hypertension (elevated blood pressure)\nobservations:\n* Blood pressure: 140/90 mmHg\nmedications: Not available\nprocedures: Not available\n\nNote that some of the entities, such as age and gender, are not explicitly mentioned in the text. However, based on the context and the information provided, we can infer them.'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '11',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.462+00:00',
#    'source': '#ui8ZxrgObdSuyebo',
#    'versionId': '1'},
#   'code': {'text': ' An insulin sensitivity test conducted on Mr. Doe revealed a significantly reduced sensitivity to insulin. This information will guide adjustments to his insulin regimen and reinforce the importance of lifestyle modifications.'},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': "  Sure! Here are the entities in the format you requested:\nage: Not available (as it is not mentioned in the text)\ngender: Male (as the patient's gender is inferred from their name)\nconditions: Insulin sensitivity test\nobservations:\n* Lab data: Not available (as it is not mentioned in the text)\n* Measurements: Not available (as it is not mentioned in the text)\n* Vital signs: Not available (as it is not mentioned in the text)\n* Clinical findings: Reduced insulin sensitivity\n* Various scores: Not available (as it is not mentioned in the text)\nmedications:\n* Medication name: Insulin\n* Dose: Not available (as it is not mentioned in the text)\n* Frequency: Not available (as it is not mentioned in the text)\nprocedures:\n* Procedure name: Insulin sensitivity test\n* Therapy or test performed: None (as it is only mentioned that a test was conducted on the patient)"}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '12',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.542+00:00',
#    'source': '#icBF13cziSQQ3GdX',
#    'versionId': '1'},
#   'code': {'text': " Mr. Doe's recent bloodwork highlighted a triglyceride level of 250 mg/dL, along with elevated LDL cholesterol. Addressing these lipid abnormalities alongside his diabetes management is crucial for minimizing cardiovascular risks."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities extracted from the text:\nage: Not available\ngender: Male (Mr.)\nconditions:\n* Lipid abnormalities (triglyceride level of 250 mg/dL, elevated LDL cholesterol)\nobservations:\n* Bloodwork results (triglyceride level of 250 mg/dL, elevated LDL cholesterol)\nmedications: Not available\nprocedures: Not available\nNote that some of the entities mentioned in the text, such as age and gender, are not explicitly provided. However, based on the context, it can be inferred that Mr. Doe is an adult male with diabetes and lipid abnormalities.'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '13',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.596+00:00',
#    'source': '#TvxFn5CrrpHONzjJ',
#    'versionId': '1'},
#   'code': {'text': ' Mr. John Doe, diagnosed with stage III lung cancer, presented with persistent cough, shortness of breath, and weight loss. A chest X-ray revealed a large mass in the left lung, and a biopsy confirmed adenocarcinoma. Oncology consultation has been scheduled for further evaluation and treatment planning.'},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities extracted from the text:\n\nage: Not available\ngender: Male\nconditions:\n* Persistent cough\n* Shortness of breath\n* Weight loss\nobservations:\n\nlab data: Not available\nmeasurements: Not available\nvital signs: Not available\nclinical findings:\n* Large mass in the left lung (confirmed by biopsy)\nscores: Not available\nmedications: Not available\nprocedures:\n* Oncology consultation scheduled for further evaluation and treatment planning.'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '14',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.667+00:00',
#    'source': '#6mCEN0IgUpCFIwqH',
#    'versionId': '1'},
#   'code': {'text': " Following a series of imaging studies, it was determined that Mr. Doe's pancreatic mass is consistent with adenocarcinoma. His CA 19-9 tumor marker levels were elevated, indicating potential disease progression. Multidisciplinary discussions are ongoing to decide on appropriate treatment options."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities extracted from the text:\n\nage: Not available\ngender: Male\nconditions: pancreatic mass; tumor marker levels elevated\nobservations:\n* Lab data: Not available\n* Measurements: Not available\n* Vital signs: Not available\n* Clinical findings: Consistent with adenocarcinoma\n* Various scores: Not available\nmedications:\n* Statement 1: No medication information available\nprocedures:\n* Procedure 1: Not available\nNote that some of the entities may not be available or may be incomplete in the given text, as they are dependent on the specific information provided.'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '15',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.708+00:00',
#    'source': '#H1RcMpCfQ4SOhRbp',
#    'versionId': '1'},
#   'code': {'text': " Mr. Doe's recent PET-CT scan showed increased uptake in the lymph nodes, indicating possible metastasis of his colon cancer. Given the aggressive nature of the disease, discussions are underway to explore targeted therapies and clinical trial participation."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': "  Sure! Here are the entities extracted from the text:\nage: Not available\ngender: Male\nconditions:\n* Colon cancer\nobservations:\n* PET-CT scan\n* Increased uptake in lymph nodes\nmedications: Not available\nprocedures: Not available\nNote that some of these entities may not be explicitly mentioned in the text, but can be inferred based on the context. For example, the patient's age and gender are not explicitly mentioned, but can be inferred based on the language used in the text. Similarly, the patient's conditions and observations can be inferred from the information provided in the text."}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '16',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.749+00:00',
#    'source': '#E3xdyedO6kXqUZjg',
#    'versionId': '1'},
#   'code': {'text': " After undergoing surgery for prostate cancer, Mr. Doe's post-operative PSA level remains elevated, suggesting the presence of residual disease. Additional imaging and further treatment planning are necessary to address this recurrence."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': "  Sure! Here are the entities in the format you requested:\nage: Not available (as it is not mentioned in the text)\ngender: Male (as the patient's gender is inferred from their name)\nconditions:\n* Prostate cancer (as mentioned in the text)\nobservations:\n* PSA level remains elevated (as mentioned in the text)\n* Additional imaging and further treatment planning are necessary (as mentioned in the text)\nmedications: Not available (as there is no information about medication use in the text)\nprocedures:\n* Surgery for prostate cancer (as mentioned in the text)"}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '17',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.790+00:00',
#    'source': '#Wd3J1mBbcJwehll0',
#    'versionId': '1'},
#   'code': {'text': ' Mr. Doe, diagnosed with stage IV breast cancer, experienced worsening bone pain and was found to have multiple bone metastases on a bone scan. Palliative radiation therapy has been initiated to alleviate discomfort and improve quality of life.'},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities in the format you requested:\nage: Not available (as it is not mentioned in the text)\ngender: Male (based on the name "Mr. Doe")\nconditions:\n* Breast cancer (diagnosis)\n* Worsening bone pain (symptom)\n* Multiple bone metastases (diagnosis)\nobservations:\n* Bone scan (procedure)\n* Palliative radiation therapy (procedure)\nmedications: Not available (as there is no information about medication use in the text)\nprocedures:\n* Bone scan (procedure)\n* Radiation therapy (procedure)'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '18',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.830+00:00',
#    'source': '#lnj8RovjgkLC1akT',
#    'versionId': '1'},
#   'code': {'text': " During a routine follow-up, imaging revealed progression of Mr. Doe's glioblastoma multiforme with increased edema. His neurological symptoms have worsened, warranting a discussion about potential changes in his treatment plan and supportive care."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': "  Sure! Here are the entities that can be extracted from the text you provided:\nage: Not available\ngender: Male (Mr. Doe)\nconditions:\n* Glioblastoma multiforme (a type of brain cancer)\nobservations:\n* Imaging revealed progression of the patient's glioblastoma multiforme with increased edema (swelling)\n* Neurological symptoms have worsened\nmedications: Not available\nprocedures: Not available\nscores: Not available"}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '19',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.873+00:00',
#    'source': '#K7iA0W5ipUzFdhSJ',
#    'versionId': '1'},
#   'code': {'text': " Mr. Doe's lymphoma biopsy confirmed diffuse large B-cell lymphoma. His recent CT scan showed extensive lymphadenopathy and splenomegaly. Chemotherapy initiation is planned to target the malignancy and achieve disease remission."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities extracted from the text:\nage: Not available\ngender: Male\nconditions:\n* Diffuse large B-cell lymphoma (diagnosis)\nobservations:\n* CT scan (lab data)\n* Extensive lymphadenopathy (clinical finding)\n* Splenomegaly (clinical finding)\nmedications: Not available\nprocedures:\n* Chemotherapy (therapy)\n* Lymphoma biopsy (procedure)'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '20',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.941+00:00',
#    'source': '#hGQqeEGdiksUusIa',
#    'versionId': '1'},
#   'code': {'text': " Following a radical nephrectomy for kidney cancer, Mr. Doe's pathology report indicated clear cell carcinoma. His recovery has been favorable, and ongoing surveillance will monitor for any signs of recurrence or metastasis."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': "  Sure! Here are the entities in the format you requested:\nage: Not available (as it is not mentioned in the text)\ngender: Male (as the patient's gender is inferred based on their name)\nconditions:\n* Clear cell carcinoma (as mentioned in the pathology report)\nobservations:\n* Lab data: Not available (as there is no mention of lab data in the text)\n* Measurements: Not available (as there is no mention of measurements in the text)\n* Vital signs: Not available (as there is no mention of vital signs in the text)\n* Clinical findings: Favorable recovery (as mentioned in the text)\n* Various scores: Not available (as there is no mention of any scores in the text)\nmedications:\n* None mentioned (as there is no mention of any medication use by the patient in the text)\nprocedures:\n* Radical nephrectomy (as mentioned in the text as the surgical procedure performed on the patient)"}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '21',
#   'meta': {'lastUpdated': '2023-08-21T12:36:42.987+00:00',
#    'source': '#ZiIxDnE1YbBm5KKU',
#    'versionId': '1'},
#   'code': {'text': ' Mr. Doe, diagnosed with stage II colorectal cancer, underwent successful surgery to remove the tumor. Post-operative recovery has been smooth, and discussions about adjuvant therapy to reduce the risk of recurrence are underway.'},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities that can be extracted from the text you provided:\nage: Not available\ngender: Male (Mr.)\nconditions:\n* Colorectal cancer (stage II)\nobservations:\n* Post-operative recovery has been smooth\n* Discussions about adjuvant therapy to reduce the risk of recurrence are underway\nmedications: Not available\nprocedures:\n* Surgery to remove the tumor (not specified)\nNote that some of these entities may not be explicitly mentioned in the text, but can be inferred based on the information provided.'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'},
#  {'id': '22',
#   'meta': {'lastUpdated': '2023-08-21T12:36:43.049+00:00',
#    'source': '#n9VOtw2J78Y3lmI3',
#    'versionId': '1'},
#   'code': {'text': " Mr. Doe's recent bone marrow biopsy confirmed acute myeloid leukemia. His blood counts are rapidly declining, necessitating prompt initiation of intensive chemotherapy to achieve remission and prevent disease progression."},
#   'note': [{'authorString': 'Annotated by LLama2',
#     'text': '  Sure! Here are the entities extracted from the text:\n\nage: Not available\ngender: Male\nconditions: acute myeloid leukemia\nobservations:\n* Lab data: Not available\n* Measurements: Not available\n* Vital signs: Not available\n* Clinical findings: Rapidly declining blood counts\n* Various scores: Not available\nmedications:\n* Medication name: Not available\n* Dose: Not available\n* Frequency: Not available\nprocedures:\n* Procedure name: Not available\n* Therapy: Not available\n* Tests performed: Not available'}],
#   'status': 'final',
#   'subject': {'display': 'John Dae', 'reference': 'Patient/1'},
#   'resourceType': 'Observation'}]

# %%
with open('../data/test_results.pkl', 'rb') as file:
    result = pickle.load(file)

def _parse_line_to_dict(line, sv, cls_name):
    logging.info(f"PARSING LINE: {line}")
    field, val = line.split(":", 1)
    # Field nornalization:
    # The LLML may mutate the output format somewhat,
    # randomly pluralizing or replacing spaces with underscores
    field = field.lower().replace(" ", "_")
    cls_slots = sv.class_slots(cls.name)
    slot = None
    if field in cls_slots:
        slot = sv.induced_slot(field, cls.name)
    else:
        if field.endswith("s"):
            field = field[:-1]
        if field in cls_slots:
            slot = sv.induced_slot(field, cls.name)
    if not slot:
        logging.error(f"Cannot find slot for {field} in {line}")
        # raise ValueError(f"Cannot find slot for {field} in {line}")
        return
    if not val:
        msg = f"Empty value in key-value line: {line}"
        if slot.required:
            raise ValueError(msg)
        if slot.recommended:
            logging.warning(msg)
        return
    inlined = slot.inlined
    slot_range = sv.get_class(slot.range)
    if not inlined:
        if slot.range in sv.all_classes():
            inlined = sv.get_identifier_slot(slot_range.name) is None
    val = val.strip()
    if slot.multivalued:
        vals = [v.strip() for v in val.split(";")]
    else:
        vals = [val]
    vals = [val for val in vals if val]
    logging.debug(f"SLOT: {slot.name} INL: {inlined} VALS: {vals}")
    if inlined:
        transformed = False
        slots_of_range = sv.class_slots(slot_range.name)
        if len(slots_of_range) > 2:
            vals = [self._extract_from_text_to_dict(v, slot_range) for v in vals]
        else:
            for sep in [" - ", ":", "/", "*", "-"]:
                if all([sep in v for v in vals]):
                    vals = [dict(zip(slots_of_range, v.split(sep, 1))) for v in vals]
                    for v in vals:
                        for k in v.keys():
                            v[k] = v[k].strip()
                    transformed = True
                    break
            if not transformed:
                logging.warning(f"Did not find separator in {vals} for line {line}")
                return
    # transform back from list to single value if not multivalued
    if slot.multivalued:
        final_val = vals
    else:
        if len(vals) != 1:
            logging.error(f"Expected 1 value for {slot.name} in '{line}' but got {vals}")
        final_val = vals[0]
    return field, final_val

def parse_response_to_dict(result, cls_name, sv):
    lines = result.splitlines()
    ann = {}
    promptable_slots = sv.class_induced_slots(cls_name)
    for line in lines:
        line = line.strip()
        if not line:
            continue
        if ":" not in line:
            if len(promptable_slots) == 1:
                slot = promptable_slots[0]
                logging.warning(
                    f"Coercing to YAML-like with key {slot.name}: Original line: {line}"
                )
                line = f"{slot.name}: {line}"
            else:
                logging.error(f"Line '{line}' does not contain a colon; ignoring")
                return
        r = parse_line_to_dict(line, cls_name)
        if r is not None:
            field, val = r
            ann[field] = val
    return ann

def _extract_from_text_to_dict(self, text: str, cls: ClassDefinition = None) -> RESPONSE_DICT:
    raw_text = self._raw_extract(text, cls)
    return parse_response_to_dict(raw_text, cls)

ann = parse_response_to_dict(
    result = result, 
    cls_name = 'ClinicalNote', 
    sv = sv
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 28
#      25             ann[field] = val
#      26     return ann
# ---> 28 ann = parse_response_to_dict(
#      29     result = result,
#      30     cls_name = 'ClinicalNote',
#      31     sv = sv
#      32 )
#
# Cell In[26], line 22, in parse_response_to_dict(result, cls_name, sv)
#      20         logging.error(f"Line '{line}' does not contain a colon; ignoring")
#      21         return
# ---> 22 r = self._parse_line_to_dict(line, cls)
#      23 if r is not None:
#      24     field, val = r
#
# NameError: name 'self' is not defined
