# %%
# logger
import logging
logging.basicConfig(filename='logs.txt',
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.DEBUG)
logger = logging.getLogger()
logger.setLevel(level=logging.DEBUG)

# imports
import os
import ast
import datetime
from fhirclient.client import FHIRClient
import configparser
import gradio_client
import fhirclient.models.observation as o
import fhirclient.models.annotation as a
from fhirclient.models.fhirdate import FHIRDate
from linkml_runtime import SchemaView
import pickle

# get the config
config = configparser.ConfigParser()
config.read('../config.ini')

# environment var
os.environ['OPENAI_API_KEY'] = config['AZURE']['AZURE_API_KEY']

# connection to FHIR server
settings = {
    'app_id': 'my_web_app',
    'api_base': 'http://localhost:8080/fhir/'
}
fhir_client = FHIRClient(settings=settings)

# connection to Gradlio server
HOST_URL = "http://localhost:7860"
llm_client = gradio_client.Client(HOST_URL)

# get observations
search = o.Observation.where(struct={'status': 'final'})
observations = search.perform_resources(fhir_client.server)

# load LinkML template
path_to_template = 'test.yaml'
sv = SchemaView(path_to_template)

# llm call function
def run_llm(prompt):

    # string of dict for input
    kwargs = dict(instruction_nochat=prompt)
    res = llm_client.predict(str(dict(kwargs)), api_name='/submit_nochat_api')

    # string of dict for output
    return ast.literal_eval(res)['response']

def get_completion_prompt(cls_name, sv, text):
    """Get the prompt for the given template."""

    # system prompt
    prompt = (
        "Do not provide any explanations and just extract the entities (if available) from the text below in the following format:\n\n"
    )

    # schema prompt is concatinated from prompts for each entity group
    for slot in sv.class_induced_slots(cls_name):
        
        # description of the entity group
        slot_prompt = slot.description

        # custom instruction for categorical entities
        if slot.range in sv.all_enums():
            enum_def = sv.get_enum(slot.range)
            pvs = [str(k) for k in enum_def.permissible_values.keys()]
            slot_prompt += f"Must be one of: {', '.join(pvs)}"

        # entity group prompt
        prompt += f"{slot.name}: <{slot_prompt}>\n"
    
    # concatinate the prompt with doctor's note
    prompt = f"{prompt}\n\nText:\n{text}\n\n===\n\n"
    return prompt

# preprocess annotation
def preprocessing(ann_text):

    # strip
    ann_text = ann_text.strip()

    # lower
    ann_text = ann_text.lower()

    # delete intro
    ann_text = ann_text[ann_text.find('age'):]

    # remove stars
    ann_text = ann_text.replace('*','')

    # remove new lines
    ann_text = ann_text.replace('\n',' ')

    # add new lines to sections
    ann_text = ann_text.replace('gender:','\ngender:')
    ann_text = ann_text.replace('conditions:','\nconditions:')
    ann_text = ann_text.replace('observations:','\nobservations:')
    ann_text = ann_text.replace('medications:','\nmedications:')
    ann_text = ann_text.replace('procedures:','\nprocedures:')
    return ann_text

def annotate_observation(observation):
    
    # generate the prompt
    prompt = get_completion_prompt(
        cls_name='ClinicalNote',
        sv=sv,
        text = observation.code.text
    )
    
    # LLM call to extract entities 
    result = run_llm(prompt)

    # preprocess annotation text
    result = preprocessing(result)
    
    # update observation
    observation.note = [a.Annotation({
        "authorString" : "Raw annotations from LLama2",
        "text": result
    })]
    observation.meta.lastUpdated = FHIRDate(
        datetime.datetime.now().strftime('%Y-%m-%dT%H:%M:%S')
    )
    observation.update(fhir_client.server)

    return result
# Out:
# Loaded as API: http://localhost:7860/ ✔

# %%
# annotate all observations
for observation in observations:
    annotate_observation(observation)

# %%
len(observations)
# Out:
# 20

# %%
with open('../data/observations_with_annotations.pkl', 'wb') as file:
    pickle.dump(observations_as_json, file)

# %%
observations_as_json = [a.as_json() for a in observations]

# %%
with open('../data/observations_with_annotations.pkl', 'rb') as file:
    test = pickle.load(file)
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 with open('../data/observations_with_annotations.pkl', 'rb') as file:
# ----> 2     test = pickle.load(file)
#       3 test
#
# NameError: name 'pickle' is not defined

# %%
##################
# FROM ACCENTURE #
##################

# logger
import logging
logging.basicConfig(filename='logs.txt',
                    filemode='a',
                    format='%(asctime)s,%(msecs)d %(name)s %(levelname)s %(message)s',
                    datefmt='%H:%M:%S',
                    level=logging.DEBUG)
logger = logging.getLogger()
logger.setLevel(level=logging.DEBUG)

# imports
import pickle
import fhirclient.models.observation as o
from linkml_runtime import SchemaView

# load data
with open('../data/observations_with_annotations.pkl', 'rb') as file:
    observations_as_json = pickle.load(file)
observations = [o.Observation(a) for a in observations_as_json]

# load LinkML template
path_to_template = 'test.yaml'
sv = SchemaView(path_to_template)

# parse a parameter annotation (1 line)
def _parse_line_to_dict(line, sv, cls_name):
    
    # log
    logging.info(f"PARSING LINE: {line}")
    field, val = line.split(":", 1)
    
    # test if value is valid
    value_valid = True
    val = val.strip()
    if val.find('not available') != -1:
        value_valid = False

    # process value only if valid
    if value_valid:

        # Field nornalization:
        # The LLML may mutate the output format somewhat,
        # randomly pluralizing or replacing spaces with underscores
        field = field.lower().replace(" ", "_")
        cls_slots = sv.class_slots(cls_name)
        slot = None
        if field in cls_slots:
            slot = sv.induced_slot(field, cls_name)
        else:
            if field.endswith("s"):
                field = field[:-1]
            if field in cls_slots:
                slot = sv.induced_slot(field, cls_name)
        if not slot:
            logging.error(f"Cannot find slot for {field} in {line}")
            # raise ValueError(f"Cannot find slot for {field} in {line}")
            return
        if not val:
            msg = f"Empty value in key-value line: {line}"
            if slot.required:
                raise ValueError(msg)
            if slot.recommended:
                logging.warning(msg)
            return
        inlined = slot.inlined
        slot_range = sv.get_class(slot.range)
        if not inlined:
            if slot.range in sv.all_classes():
                inlined = sv.get_identifier_slot(slot_range.name) is None
        val = val.strip()
        if slot.multivalued:
            vals = [v.strip() for v in val.split(";")]
        else:
            vals = [val]
        vals = [val for val in vals if val]
        logging.debug(f"SLOT: {slot.name} INL: {inlined} VALS: {vals}")
        # transform back from list to single value if not multivalued
        if slot.multivalued:
            final_val = vals
        else:
            if len(vals) != 1:
                logging.error(f"Expected 1 value for {slot.name} in '{line}' but got {vals}")
            final_val = vals[0]
        return field, final_val
    return field, None

# parse a record LLM annotation result line by line
def parse_response_to_dict(result, cls_name, sv):

    # preprocess the LLM output
    result = preprocessing(result)

    # process line by line
    lines = result.splitlines()
    ann = {}
    promptable_slots = sv.class_induced_slots(cls_name)
    for line in lines:
        line = line.strip()
        if not line:
            continue
        if ":" not in line:
            if len(promptable_slots) == 1:
                slot = promptable_slots[0]
                logging.warning(
                    f"Coercing to YAML-like with key {slot.name}: Original line: {line}"
                )
                line = f"{slot.name}: {line}"
            else:
                logging.error(f"Line '{line}' does not contain a colon; ignoring")
                return
        r = _parse_line_to_dict(line, sv, cls_name)
        if r is not None:
            field, val = r
            ann[field] = val
    return ann

# process all records
for observation in observations:
    ann = parse_response_to_dict(
        result = observation.note[0].text, 
        cls_name = 'ClinicalNote', 
        sv = sv
    )

ann
# Out:
# {'age': None,
#  'gender': 'male',
#  'conditions': ['acute myeloid leukemia'],
#  'observations': None,
#  'medications': None,
#  'procedures': None}

# %%
# Out:
# INFO:root:PARSING LINE: age: not available (as it is not mentioned in the text)
# INFO:root:PARSING LINE: gender: male (as the patient's name is "mr. john doe")
# DEBUG:root:SLOT: gender INL: None VALS: ['male (as the patient\'s name is "mr. john doe")']
# INFO:root:PARSING LINE: conditions:  diabetes management
# DEBUG:root:SLOT: conditions INL: None VALS: ['diabetes management']
# INFO:root:PARSING LINE: observations:  blood glucose level: 175 mg/dl (measured during today's check-up)
# DEBUG:root:SLOT: observations INL: None VALS: ["blood glucose level: 175 mg/dl (measured during today's check-up)"]
# INFO:root:PARSING LINE: medications: not available (as the text does not mention any medication use by the patient)
# INFO:root:PARSING LINE: procedures: not available (as the text does not mention any procedures or therapies performed on the patient)
# INFO:root:PARSING LINE: age: not available (as it is not mentioned in the text)
# INFO:root:PARSING LINE: gender: male (as the patient's name, mr. doe, suggests a male gender)
# DEBUG:root:SLOT: gender INL: None VALS: ["male (as the patient's name, mr. doe, suggests a male gender)"]
# INFO:root:PARSING LINE: conditions: diabetes (as the text mentions the patient has diabetes and suggests a need for closer glycemic control and potential adjustments to his insulin regimen)
# DEBUG:root:SLOT: conditions INL: None VALS: ['diabetes (as the text mentions the patient has diabetes and suggests a need for closer glycemic control and potential adjustments to his insulin regimen)']
# INFO:root:PARSING LINE: observations:  lab results: fasting blood sugar level of 190 mg/dl
# DEBUG:root:SLOT: observations INL: None VALS: ['lab results: fasting blood sugar level of 190 mg/dl']
# INFO:root:PARSING LINE: medications: not available (as the text does not mention any information about medication use by the patient)
# INFO:root:PARSING LINE: procedures: not available (as the text does not mention any procedures or therapies performed on the patient)
# INFO:root:PARSING LINE: age: not available (the patient's age is not mentioned in the text)
# INFO:root:PARSING LINE: gender: male (based on the name "mr. doe")
# DEBUG:root:SLOT: gender INL: None VALS: ['male (based on the name "mr. doe")']
# INFO:root:PARSING LINE: conditions:  increased thirst  frequent urination
# DEBUG:root:SLOT: conditions INL: None VALS: ['increased thirst  frequent urination']
# INFO:root:PARSING LINE: observations:  hemoglobin a1c level: 8.9%  optimal blood sugar control
# DEBUG:root:SLOT: observations INL: None VALS: ['hemoglobin a1c level: 8.9%  optimal blood sugar control']
# INFO:root:PARSING LINE: medications: not available (the text does not mention any medication use by the patient)
# INFO:root:PARSING LINE: procedures: not available (the text does not mention any procedures or therapies performed on the patient)
# INFO:root:PARSING LINE: age: not available in the given text.
# INFO:root:PARSING LINE: gender: male (based on the name "mr. doe")
# DEBUG:root:SLOT: gender INL: None VALS: ['male (based on the name "mr. doe")']
# INFO:root:PARSING LINE: conditions: hyperglycemia (raised as a concern due to continued high blood glucose levels)
# DEBUG:root:SLOT: conditions INL: None VALS: ['hyperglycemia (raised as a concern due to continued high blood glucose levels)']
# INFO:root:PARSING LINE: observations: 	+ lab data: not available in the given text. 	+ measurements: not available in the given text. 	+ vital signs: not available in the given text. 	+ clinical findings: none mentioned in the given text. 	+ various scores: not available in the given text.
# INFO:root:PARSING LINE: medications: 	+ medication name: not available in the given text. 	+ dose: not available in the given text. 	+ frequency: not available in the given text.
# INFO:root:PARSING LINE: procedures: none mentioned in the given text.  tests: none mentioned in the given text.
# DEBUG:root:SLOT: procedures INL: None VALS: ['none mentioned in the given text.  tests: none mentioned in the given text.']
# INFO:root:PARSING LINE: age: not available
# INFO:root:PARSING LINE: gender: male
# DEBUG:root:SLOT: gender INL: None VALS: ['male']
# INFO:root:PARSING LINE: conditions: hypoglycemic event
# DEBUG:root:SLOT: conditions INL: None VALS: ['hypoglycemic event']
# INFO:root:PARSING LINE: observations:  lab data: blood sugar level: 55 mg/dl  measurements: none mentioned  vital signs: none mentioned  clinical findings: nocturnal hypoglycemic event  various scores: none mentioned
# DEBUG:root:SLOT: observations INL: None VALS: ['lab data: blood sugar level: 55 mg/dl  measurements: none mentioned  vital signs: none mentioned  clinical findings: nocturnal hypoglycemic event  various scores: none mentioned']
# INFO:root:PARSING LINE: medications:  insulin dosing: adjustments made to his insulin dosing  dose: not available  frequency: not available
# INFO:root:PARSING LINE: procedures:  continuous glucose monitoring: performed on the patient  other procedures and therapies: none mentioned
# DEBUG:root:SLOT: procedures INL: None VALS: ['continuous glucose monitoring: performed on the patient  other procedures and therapies: none mentioned']
# INFO:root:PARSING LINE: age: not available (as it is not mentioned in the text)
# INFO:root:PARSING LINE: gender: male (as the patient's name is mr. doe, which is typically used for male patients)
# DEBUG:root:SLOT: gender INL: None VALS: ["male (as the patient's name is mr. doe, which is typically used for male patients)"]
# INFO:root:PARSING LINE: conditions:  elevated random blood glucose level (as mentioned in the text)
# DEBUG:root:SLOT: conditions INL: None VALS: ['elevated random blood glucose level (as mentioned in the text)']
# INFO:root:PARSING LINE: observations:  random blood glucose level: 240 mg/dl (as mentioned in the text)
# DEBUG:root:SLOT: observations INL: None VALS: ['random blood glucose level: 240 mg/dl (as mentioned in the text)']
# INFO:root:PARSING LINE: medications: not available (as there is no information about medication use in the text)
# INFO:root:PARSING LINE: procedures: not available (as there is no information about procedures or therapies performed on the patient in the text)
# INFO:root:PARSING LINE: age: not available
# INFO:root:PARSING LINE: gender: male (mr.)
# DEBUG:root:SLOT: gender INL: None VALS: ['male (mr.)']
# INFO:root:PARSING LINE: conditions: diabetes
# DEBUG:root:SLOT: conditions INL: None VALS: ['diabetes']
# INFO:root:PARSING LINE: observations:  hba1c measurement: 9.4%
# DEBUG:root:SLOT: observations INL: None VALS: ['hba1c measurement: 9.4%']
# INFO:root:PARSING LINE: medications: not available
# INFO:root:PARSING LINE: procedures: not available  note that some of these entities may not be explicitly mentioned in the text, but can be inferred based on the information provided.
# INFO:root:PARSING LINE: age: not available
# INFO:root:PARSING LINE: gender: male (mr. doe)
# DEBUG:root:SLOT: gender INL: None VALS: ['male (mr. doe)']
# INFO:root:PARSING LINE: conditions:  hypertension (elevated blood pressure)
# DEBUG:root:SLOT: conditions INL: None VALS: ['hypertension (elevated blood pressure)']
# INFO:root:PARSING LINE: observations:  blood pressure: 140/90 mmhg
# DEBUG:root:SLOT: observations INL: None VALS: ['blood pressure: 140/90 mmhg']
# INFO:root:PARSING LINE: medications: not available
# INFO:root:PARSING LINE: procedures: not available  note that some of the entities, such as age and gender, are not explicitly mentioned in the text. however, based on the context and the information provided, we can infer them.
# INFO:root:PARSING LINE: age: not available (as it is not mentioned in the text)
# INFO:root:PARSING LINE: gender: male (as the patient's gender is inferred from their name)
# DEBUG:root:SLOT: gender INL: None VALS: ["male (as the patient's gender is inferred from their name)"]
# INFO:root:PARSING LINE: conditions: insulin sensitivity test
# DEBUG:root:SLOT: conditions INL: None VALS: ['insulin sensitivity test']
# INFO:root:PARSING LINE: observations:  lab data: not available (as it is not mentioned in the text)  measurements: not available (as it is not mentioned in the text)  vital signs: not available (as it is not mentioned in the text)  clinical findings: reduced insulin sensitivity  various scores: not available (as it is not mentioned in the text)
# INFO:root:PARSING LINE: medications:  medication name: insulin  dose: not available (as it is not mentioned in the text)  frequency: not available (as it is not mentioned in the text)
# INFO:root:PARSING LINE: procedures:  procedure name: insulin sensitivity test  therapy or test performed: none (as it is only mentioned that a test was conducted on the patient)
# DEBUG:root:SLOT: procedures INL: None VALS: ['procedure name: insulin sensitivity test  therapy or test performed: none (as it is only mentioned that a test was conducted on the patient)']
# INFO:root:PARSING LINE: age: not available
# INFO:root:PARSING LINE: gender: male (mr.)
# DEBUG:root:SLOT: gender INL: None VALS: ['male (mr.)']
# INFO:root:PARSING LINE: conditions:  lipid abnormalities (triglyceride level of 250 mg/dl, elevated ldl cholesterol)
# DEBUG:root:SLOT: conditions INL: None VALS: ['lipid abnormalities (triglyceride level of 250 mg/dl, elevated ldl cholesterol)']
# INFO:root:PARSING LINE: observations:  bloodwork results (triglyceride level of 250 mg/dl, elevated ldl cholesterol)
# DEBUG:root:SLOT: observations INL: None VALS: ['bloodwork results (triglyceride level of 250 mg/dl, elevated ldl cholesterol)']
# INFO:root:PARSING LINE: medications: not available
# INFO:root:PARSING LINE: procedures: not available note that some of the entities mentioned in the text, such as age and gender, are not explicitly provided. however, based on the context, it can be inferred that mr. doe is an adult male with diabetes and lipid abnormalities.
# INFO:root:PARSING LINE: age: not available
# INFO:root:PARSING LINE: gender: male
# DEBUG:root:SLOT: gender INL: None VALS: ['male']
# INFO:root:PARSING LINE: conditions:  persistent cough  shortness of breath  weight loss
# DEBUG:root:SLOT: conditions INL: None VALS: ['persistent cough  shortness of breath  weight loss']
# INFO:root:PARSING LINE: observations:  lab data: not available measurements: not available vital signs: not available clinical findings:  large mass in the left lung (confirmed by biopsy) scores: not available
# INFO:root:PARSING LINE: medications: not available
# INFO:root:PARSING LINE: procedures:  oncology consultation scheduled for further evaluation and treatment planning.
# DEBUG:root:SLOT: procedures INL: None VALS: ['oncology consultation scheduled for further evaluation and treatment planning.']
# INFO:root:PARSING LINE: age: not available
# INFO:root:PARSING LINE: gender: male
# DEBUG:root:SLOT: gender INL: None VALS: ['male']
# INFO:root:PARSING LINE: conditions: pancreatic mass; tumor marker levels elevated
# DEBUG:root:SLOT: conditions INL: None VALS: ['pancreatic mass', 'tumor marker levels elevated']
# INFO:root:PARSING LINE: observations:  lab data: not available  measurements: not available  vital signs: not available  clinical findings: consistent with adenocarcinoma  various scores: not available
# INFO:root:PARSING LINE: medications:  statement 1: no medication information available
# DEBUG:root:SLOT: medications INL: None VALS: ['statement 1: no medication information available']
# INFO:root:PARSING LINE: procedures:  procedure 1: not available note that some of the entities may not be available or may be incomplete in the given text, as they are dependent on the specific information provided.
# INFO:root:PARSING LINE: age: not available
# INFO:root:PARSING LINE: gender: male
# DEBUG:root:SLOT: gender INL: None VALS: ['male']
# INFO:root:PARSING LINE: conditions:  colon cancer
# DEBUG:root:SLOT: conditions INL: None VALS: ['colon cancer']
# INFO:root:PARSING LINE: observations:  pet-ct scan  increased uptake in lymph nodes
# DEBUG:root:SLOT: observations INL: None VALS: ['pet-ct scan  increased uptake in lymph nodes']
# INFO:root:PARSING LINE: medications: not available
# INFO:root:PARSING LINE: procedures: not available note that some of these entities may not be explicitly mentioned in the text, but can be inferred based on the context. for example, the patient's age and gender are not explicitly mentioned, but can be inferred based on the language used in the text. similarly, the patient's conditions and observations can be inferred from the information provided in the text.
# INFO:root:PARSING LINE: age: not available (as it is not mentioned in the text)
# INFO:root:PARSING LINE: gender: male (as the patient's gender is inferred from their name)
# DEBUG:root:SLOT: gender INL: None VALS: ["male (as the patient's gender is inferred from their name)"]
# INFO:root:PARSING LINE: conditions:  prostate cancer (as mentioned in the text)
# DEBUG:root:SLOT: conditions INL: None VALS: ['prostate cancer (as mentioned in the text)']
# INFO:root:PARSING LINE: observations:  psa level remains elevated (as mentioned in the text)  additional imaging and further treatment planning are necessary (as mentioned in the text)
# DEBUG:root:SLOT: observations INL: None VALS: ['psa level remains elevated (as mentioned in the text)  additional imaging and further treatment planning are necessary (as mentioned in the text)']
# INFO:root:PARSING LINE: medications: not available (as there is no information about medication use in the text)
# INFO:root:PARSING LINE: procedures:  surgery for prostate cancer (as mentioned in the text)
# DEBUG:root:SLOT: procedures INL: None VALS: ['surgery for prostate cancer (as mentioned in the text)']
# INFO:root:PARSING LINE: age: not available (as it is not mentioned in the text)
# INFO:root:PARSING LINE: gender: male (based on the name "mr. doe")
# DEBUG:root:SLOT: gender INL: None VALS: ['male (based on the name "mr. doe")']
# INFO:root:PARSING LINE: conditions:  breast cancer (diagnosis)  worsening bone pain (symptom)  multiple bone metastases (diagnosis)
# DEBUG:root:SLOT: conditions INL: None VALS: ['breast cancer (diagnosis)  worsening bone pain (symptom)  multiple bone metastases (diagnosis)']
# INFO:root:PARSING LINE: observations:  bone scan (procedure)  palliative radiation therapy (procedure)
# DEBUG:root:SLOT: observations INL: None VALS: ['bone scan (procedure)  palliative radiation therapy (procedure)']
# INFO:root:PARSING LINE: medications: not available (as there is no information about medication use in the text)
# INFO:root:PARSING LINE: procedures:  bone scan (procedure)  radiation therapy (procedure)
# DEBUG:root:SLOT: procedures INL: None VALS: ['bone scan (procedure)  radiation therapy (procedure)']
# INFO:root:PARSING LINE: age: not available
# INFO:root:PARSING LINE: gender: male (mr. doe)
# DEBUG:root:SLOT: gender INL: None VALS: ['male (mr. doe)']
# INFO:root:PARSING LINE: conditions:  glioblastoma multiforme (a type of brain cancer)
# DEBUG:root:SLOT: conditions INL: None VALS: ['glioblastoma multiforme (a type of brain cancer)']
# INFO:root:PARSING LINE: observations:  imaging revealed progression of the patient's glioblastoma multiforme with increased edema (swelling)  neurological symptoms have worsened
# DEBUG:root:SLOT: observations INL: None VALS: ["imaging revealed progression of the patient's glioblastoma multiforme with increased edema (swelling)  neurological symptoms have worsened"]
# INFO:root:PARSING LINE: medications: not available
# INFO:root:PARSING LINE: procedures: not available scores: not available
# INFO:root:PARSING LINE: age: not available
# INFO:root:PARSING LINE: gender: male
# DEBUG:root:SLOT: gender INL: None VALS: ['male']
# INFO:root:PARSING LINE: conditions:  diffuse large b-cell lymphoma (diagnosis)
# DEBUG:root:SLOT: conditions INL: None VALS: ['diffuse large b-cell lymphoma (diagnosis)']
# INFO:root:PARSING LINE: observations:  ct scan (lab data)  extensive lymphadenopathy (clinical finding)  splenomegaly (clinical finding)
# DEBUG:root:SLOT: observations INL: None VALS: ['ct scan (lab data)  extensive lymphadenopathy (clinical finding)  splenomegaly (clinical finding)']
# INFO:root:PARSING LINE: medications: not available
# INFO:root:PARSING LINE: procedures:  chemotherapy (therapy)  lymphoma biopsy (procedure)
# DEBUG:root:SLOT: procedures INL: None VALS: ['chemotherapy (therapy)  lymphoma biopsy (procedure)']
# INFO:root:PARSING LINE: age: not available (as it is not mentioned in the text)
# INFO:root:PARSING LINE: gender: male (as the patient's gender is inferred based on their name)
# DEBUG:root:SLOT: gender INL: None VALS: ["male (as the patient's gender is inferred based on their name)"]
# INFO:root:PARSING LINE: conditions:  clear cell carcinoma (as mentioned in the pathology report)
# DEBUG:root:SLOT: conditions INL: None VALS: ['clear cell carcinoma (as mentioned in the pathology report)']
# INFO:root:PARSING LINE: observations:  lab data: not available (as there is no mention of lab data in the text)  measurements: not available (as there is no mention of measurements in the text)  vital signs: not available (as there is no mention of vital signs in the text)  clinical findings: favorable recovery (as mentioned in the text)  various scores: not available (as there is no mention of any scores in the text)
# INFO:root:PARSING LINE: medications:  none mentioned (as there is no mention of any medication use by the patient in the text)
# DEBUG:root:SLOT: medications INL: None VALS: ['none mentioned (as there is no mention of any medication use by the patient in the text)']
# INFO:root:PARSING LINE: procedures:  radical nephrectomy (as mentioned in the text as the surgical procedure performed on the patient)
# DEBUG:root:SLOT: procedures INL: None VALS: ['radical nephrectomy (as mentioned in the text as the surgical procedure performed on the patient)']
# INFO:root:PARSING LINE: age: not available
# INFO:root:PARSING LINE: gender: male (mr.)
# DEBUG:root:SLOT: gender INL: None VALS: ['male (mr.)']
# INFO:root:PARSING LINE: conditions:  colorectal cancer (stage ii)
# DEBUG:root:SLOT: conditions INL: None VALS: ['colorectal cancer (stage ii)']
# INFO:root:PARSING LINE: observations:  post-operative recovery has been smooth  discussions about adjuvant therapy to reduce the risk of recurrence are underway
# DEBUG:root:SLOT: observations INL: None VALS: ['post-operative recovery has been smooth  discussions about adjuvant therapy to reduce the risk of recurrence are underway']
# INFO:root:PARSING LINE: medications: not available
# INFO:root:PARSING LINE: procedures:  surgery to remove the tumor (not specified) note that some of these entities may not be explicitly mentioned in the text, but can be inferred based on the information provided.
# DEBUG:root:SLOT: procedures INL: None VALS: ['surgery to remove the tumor (not specified) note that some of these entities may not be explicitly mentioned in the text, but can be inferred based on the information provided.']
# INFO:root:PARSING LINE: age: not available
# INFO:root:PARSING LINE: gender: male
# DEBUG:root:SLOT: gender INL: None VALS: ['male']
# INFO:root:PARSING LINE: conditions: acute myeloid leukemia
# DEBUG:root:SLOT: conditions INL: None VALS: ['acute myeloid leukemia']
# INFO:root:PARSING LINE: observations:  lab data: not available  measurements: not available  vital signs: not available  clinical findings: rapidly declining blood counts  various scores: not available
# INFO:root:PARSING LINE: medications:  medication name: not available  dose: not available  frequency: not available
# INFO:root:PARSING LINE: procedures:  procedure name: not available  therapy: not available  tests performed: not available
# {'age': None,
#  'gender': 'male',
#  'conditions': ['acute myeloid leukemia'],
#  'observations': None,
#  'medications': None,
#  'procedures': None}

# %%
with open('../data/test_results.pkl', 'rb') as file:
    result = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 28
#      25             ann[field] = val
#      26     return ann
# ---> 28 ann = parse_response_to_dict(
#      29     result = result,
#      30     cls_name = 'ClinicalNote',
#      31     sv = sv
#      32 )
#
# Cell In[26], line 22, in parse_response_to_dict(result, cls_name, sv)
#      20         logging.error(f"Line '{line}' does not contain a colon; ignoring")
#      21         return
# ---> 22 r = self._parse_line_to_dict(line, cls)
#      23 if r is not None:
#      24     field, val = r
#
# NameError: name 'self' is not defined
